# %%
from random import randint

# %%
n = 5

# %%
def generate_matrix(size: int):
  matrix = []
  for i in range(size):
    row = []
    for j in range(size):
      row.append(randint(4,8))
    matrix.append(row)
  return matrix

# %%
A = generate_matrix(n)

# %%
A
# Out:
# [[7, 5, 4, 5, 4],
#  [6, 8, 7, 4, 5],
#  [4, 5, 6, 8, 6],
#  [8, 5, 4, 6, 7],
#  [5, 7, 7, 8, 6]]

# %%
len(A)
# Out:
# 5

# %%
with open("file.txt", "w") as file:
  file.write(f"{A}")

# %%
X = [2] * n

# %%
B = []
for i in range(len(A)):
  for j in range(len(A[i])):
    Bi =
  B.append()

# %%
for row in A:
  for i in range(len(row)):
    row[i] *= X[i]

# %%
A
# Out:
# [[14, 10, 8, 10, 8],
#  [12, 16, 14, 8, 10],
#  [8, 10, 12, 16, 12],
#  [16, 10, 8, 12, 14],
#  [10, 14, 14, 16, 12]]
