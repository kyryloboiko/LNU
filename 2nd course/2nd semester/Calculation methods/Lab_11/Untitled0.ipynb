# %%
import numpy as np

# %%
p = 2

# %%
def f(x, y):
  return (p + 4) * y * (p + 3) / (p + 4)

# %%
def separate_variables(x, y):
  dy = f(x, y) * dx
  return dy / y

# %%
def integrate_both_sides(y0, x0, x):
  ln_abs_y = (p + 3) * np.log(np.abs(y)) + C
  y = np.exp(ln_abs_y - (p + 3) * np.log(np.abs(y0)))
  return y

# %%
def find_constant_C(y0, x0):
  C = (p + 3) * np.log(np.abs(y0))
  return C

# %%
def analytical_solution(x, y0, x0):
  C = find_constant_C(y0, x0)
  y = integrate_both_sides(y0, x0, x)
  return y

# %%
x0 = 1
y0 = 1
x = np.linspace(1, 3, 100)

y_analytical = analytical_solution(x, y0, x0)

print(y_analytical)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-e4784f2f4656> in <cell line: 5>()
#       3 x = np.linspace(1, 3, 100)
#       4
# ----> 5 y_analytical = analytical_solution(x, y0, x0)
#       6
#       7 print(y_analytical)
#
# <ipython-input-11-f039c445755f> in analytical_solution(x, y0, x0)
#       1 def analytical_solution(x, y0, x0):
#       2   C = find_constant_C(y0, x0)
# ----> 3   y = integrate_both_sides(y0, x0, x)
#       4   return y
#
# <ipython-input-9-3699d7d60137> in integrate_both_sides(y0, x0, x)
#       1 def integrate_both_sides(y0, x0, x):
#       2   # Використовуємо 'y' лише як символ для інтегрування
# ----> 3   ln_abs_y = (p + 3) * np.log(np.abs(y)) + C
#       4   y = np.exp(ln_abs_y - (p + 3) * np.log(np.abs(y0)))
#       5   return y
#
# UnboundLocalError: local variable 'y' referenced before assignment
